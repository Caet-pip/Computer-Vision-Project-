# %%
# !pip install git+https://github.com/PrithivirajDamodaran/ZSIC.git
# Out:
# ...
#   Cloning https://github.com/PrithivirajDamodaran/ZSIC.git to /private/var/folders/vm/3kbc70c10gn36lc36vj2w2rw0000gn/T/pip-req-build-ld5_7nn9
#   Running command git clone --filter=blob:none --quiet https://github.com/PrithivirajDamodaran/ZSIC.git /private/var/folders/vm/3kbc70c10gn36lc36vj2w2rw0000gn/T/pip-req-build-ld5_7nn9
#   Resolved https://github.com/PrithivirajDamodaran/ZSIC.git to commit dbd1a8b7db5a7ec7fcab168e818681aa11fd95ca
#   Preparing metadata (setup.py) ... done

# %%
from ZSIC import ZeroShotImageClassification
zsic = ZeroShotImageClassification()
# Out:
# Loading OpenAI CLIP model ViT-B/32 ...
# Label language en ...

# %%
from IPython.display import Image, display
display(Image(filename="balenciaga-pulls-campaign-443-1.jpeg"))

# %%
#Balenciaga
preds = zsic(image="https://nypost.com/wp-content/uploads/sites/2/2022/11/balenciaga-pulls-campaign-443-1.jpg?quality=75&strip=all&w=1535",
            candidate_labels=["confidence","serious","inspiring","eye-opening", "sad","BDSM","Bondage","child"], 
            )
print(preds)
# Out:
# {'image': 'https://nypost.com/wp-content/uploads/sites/2/2022/11/balenciaga-pulls-campaign-443-1.jpg?quality=75&strip=all&w=1535', 'scores': (0.7252678, 0.09001978, 0.07375647, 0.04020278, 0.023562295, 0.019107698, 0.014937565, 0.013145571), 'labels': ('child', 'BDSM', 'serious', 'Bondage', 'sad', 'confidence', 'eye-opening', 'inspiring')}

# %%
from IPython.display import Image, display
display(Image(filename="colin-kaepernick-ad-float-ht-jc-180904_hpMain_4x3_992.jpeg"))

# %%
#Nike
preds = zsic(image="https://s.abcnews.com/images/Business/colin-kaepernick-ad-float-ht-jc-180904_hpMain_4x3_992.jpg",
            candidate_labels=["confidence","serious","inspiring","eye-opening", "sad","BDSM","Bondage","child"], 
            )
print(preds)
# Out:
# {'image': 'https://s.abcnews.com/images/Business/colin-kaepernick-ad-float-ht-jc-180904_hpMain_4x3_992.jpg', 'scores': (0.4859977, 0.39114004, 0.045411628, 0.044041164, 0.027618088, 0.0020392702, 0.0020315563, 0.0017205655), 'labels': ('inspiring', 'eye-opening', 'serious', 'sad', 'confidence', 'Bondage', 'child', 'BDSM')}

# %%
from IPython.display import Image, display
display(Image(filename="190219105655-burberry-noose-hoodie-super-169.jpeg"))

# %%
#Additional test run on Burberry's controversy, but as it wasn't a marketing campaign I didnt include it in the research
from ZSIC import ZeroShotImageClassification

zsic = ZeroShotImageClassification()


#Predictions
preds = zsic(image="190219105655-burberry-noose-hoodie-super-169.jpeg",
            candidate_labels=["harm","suicide","depressed","nautical"], 
            )
print(preds)
# Out:
# Loading OpenAI CLIP model ViT-B/32 ...
# Label language en ...
# {'image': '190219105655-burberry-noose-hoodie-super-169.jpeg', 'scores': (0.49851966, 0.2650675, 0.18854482, 0.047868133), 'labels': ('depressed', 'suicide', 'harm', 'nautical')}
